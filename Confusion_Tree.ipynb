# %%
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

Actual  = np.random.binomial(1,0.9,100)
Predict = np.random.binomial(1,0.9,100)

Confusion_Matrix = metrics.confusion_matrix(Actual,Predict)
CM_Display = metrics.ConfusionMatrixDisplay(confusion_matrix=Confusion_Matrix,display_labels=[False,True])

CM_Display.plot()
plt.show()

# %%
Accurancy = metrics.accuracy_score(Actual,Predict)
Precision = metrics.precision_score(Actual,Predict)
Sensitivity = metrics.recall_score(Actual,Predict)
Specificity = metrics.recall_score(Actual,Predict,pos_label=0)
F_Score = metrics.f1_score(Actual,Predict)

print({"Accurancy":Accurancy,'Precision':Precision,'Sensitivity':Sensitivity,'Specificity':Specificity,'F_Score':F_Score})
# Out:
# {'Accurancy': 0.84, 'Precision': 0.875, 'Sensitivity': 0.9545454545454546, 'Specificity': 0.0, 'F_Score': 0.9130434782608695}

# %%
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

Actual  = np.random.binomial(1,.9,1000)
Predict = np.random.binomial(1,.9,1000)

Confusion_Matrix = metrics.confusion_matrix(Actual,Predict)
CM_Display = metrics.ConfusionMatrixDisplay(confusion_matrix=Confusion_Matrix,display_labels=[True,False])

Accurancy = metrics.accuracy_score(Actual,Predict)
Precision = metrics.precision_score(Actual,Predict)
Sensitivity = metrics.recall_score(Actual,Predict)
Specificity = metrics.recall_score(Actual,Predict,pos_label=0)
f1_score = metrics.f1_score(Actual,Predict)

Data = {'Accurancy':Accurancy,'Precision':Precision,'Sensitivity':Sensitivity,'Specificity':Specificity,'f1_score':f1_score}

print(Data)
CM_Display.plot()
plt.show()
# Out:
# {'Accurancy': 0.824, 'Precision': 0.9042316258351893, 'Sensitivity': 0.9002217294900222, 'Specificity': 0.12244897959183673, 'f1_score': 0.9022222222222223}
